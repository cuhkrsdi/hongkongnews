# %%
import matplotlib.pyplot as plt
from pathlib import Path
import torch
# %matplotlib inline

# %%
# Clone weight from our Github
# !git clone ""

# %%
# Build Model
model = torch.hub.load('ultralytics/yolov5', 'custom', path='./hknews.pt')
# Out:
# Using cache found in C:\Users\b151325/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2022-10-27 Python-3.10.8 torch-1.13.0+cpu CPU
#
# Fusing layers...
# Model summary: 346 layers, 76126356 parameters, 0 gradients
# Adding AutoShape...

# %%
# Read image. Predict and save result
img = './static/19420817.jpg'
result = model(img)
result.save()

# %%
# Show predicted result
img_name = Path(img).name
img_show = plt.imread(f'./runs/detect/exp/{img_name}', format='.jpg')
plt.imshow(img_show)
